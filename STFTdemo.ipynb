#
#              85         86
# 0    -56.059464 -19.615349
# 1    -24.960369 -19.009678
# 2    -11.018116  -9.523898
# 3     -0.847368  -3.759122
# 4     -0.079115  -2.320927
# ...         ...        ...
# 1020 -77.006851 -71.438232
# 1021 -77.006851 -71.438431
# 1022 -77.006851 -71.438347
# 1023 -77.006851 -71.438614
# 1024 -77.006851 -71.438950
#
# [1025 rows x 87 columns]

# %% [markdown]
# ##  Queen Train

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/train/Queen_train/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_train_queen = pd.DataFrame()
df_merge_train_queen_mean= pd.DataFrame()
df_merge_train_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
    df_trans2 = df2.mean(axis=0).to_frame().T
    
    df_merge_train_queen_mean = pd.concat([df_merge_train_queen_mean,df_trans2], axis=0, ignore_index=True)
    df_merge_train_queen_std = pd.concat([df_merge_train_queen_std,df_trans], axis=0, ignore_index=True)
    df_merge_train_queen = pd.concat([df_merge_train_queen_mean, df_merge_train_queen_std], axis=1, ignore_index=True)

df_merge_train_queen['Label'] = 1
df_merge_train_queen
# Out:
#               0          1          2          3          4          5  \
# 0    -52.535831 -53.393600 -55.471844 -55.480797 -55.684853 -55.596523
# 1    -54.779438 -53.586079 -53.964218 -54.912586 -54.822571 -54.653843
# 2    -45.866444 -49.039345 -53.250824 -52.964169 -52.521023 -52.454994
# 3    -57.831219 -56.034870 -55.111252 -55.017120 -55.155830 -55.953594
# 4    -56.884949 -55.654720 -55.512135 -56.584679 -56.955975 -57.722878
# ...         ...        ...        ...        ...        ...        ...
# 6995 -33.122494 -37.425854 -43.271023 -43.254452 -42.761280 -42.621098
# 6996 -43.418381 -42.361507 -42.927273 -43.285305 -43.430241 -43.175831
# 6997 -61.021282 -58.537155 -57.346889 -57.492859 -58.271198 -58.470844
# 6998 -44.344315 -44.391037 -44.840038 -44.831371 -44.250347 -44.203220
# 6999 -59.683456 -57.963406 -58.064999 -58.382950 -58.488850 -58.250397
#
#               6          7          8          9  ...        165        166  \
# 0    -55.317493 -55.870838 -56.276897 -56.425091  ...  16.984747  16.923927
# 1    -54.252117 -53.679115 -52.491802 -54.089302  ...  17.303967  17.052660
# 2    -52.341812 -53.251686 -53.723415 -52.393063  ...  15.758571  15.343446
# 3    -55.854488 -56.581444 -57.092552 -57.283146  ...  17.732889  17.853344
# 4    -57.457035 -57.427814 -57.648392 -57.397785  ...  17.650028  17.640598
# ...         ...        ...        ...        ...  ...        ...        ...
# 6995 -42.976547 -43.139595 -42.458912 -41.212978  ...  15.762644  15.864411
# 6996 -42.908428 -43.283352 -43.296158 -43.490837  ...  15.598260  15.670391
# 6997 -58.787952 -58.627316 -58.437809 -58.878567  ...  16.569324  16.234354
# 6998 -44.460701 -44.390270 -42.745144 -42.578506  ...  15.573833  15.692400
# 6999 -58.219379 -57.459770 -56.196892 -56.600758  ...  15.982154  18.950251
#
#             167        168        169        170        171        172  \
# 0     17.632915  17.738434  17.348156  17.234179  17.123318  17.146439
# 1     16.931608  17.134470  17.211428  17.232468  17.197760  16.826359
# 2     15.016205  14.934757  14.902273  15.095865  15.021080  14.190903
# 3     17.658667  17.436340  17.397354  17.225203  17.523172  17.119070
# 4     17.623121  17.824034  18.212999  18.059069  18.538523  18.207346
# ...         ...        ...        ...        ...        ...        ...
# 6995  16.064104  15.821406  15.963520  16.003502  15.914512  15.592203
# 6996  15.534559  15.577766  15.819085  15.656569  15.277443  15.453741
# 6997  16.244713  16.470757  16.274191  16.062126  16.346333  16.611544
# 6998  15.881523  15.576756  15.924217  16.106958  15.871758  15.825074
# 6999  18.776346  16.084925  15.101472  15.045222  14.921356  14.219774
#
#             173  Label
# 0     14.778085      1
# 1     14.270235      1
# 2     11.676587      1
# 3     13.765302      1
# 4     14.726405      1
# ...         ...    ...
# 6995  14.941263      1
# 6996  14.203893      1
# 6997  15.884601      1
# 6998  15.246637      1
# 6999  11.684800      1
#
# [7000 rows x 175 columns]

# %% [markdown]
# ##  Not Queen Train

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/train/NonQueen_train/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_train_not_queen = pd.DataFrame()
df_merge_train_not_queen_mean= pd.DataFrame()
df_merge_train_not_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
    df_trans2 = df2.mean(axis=0).to_frame().T
    
    df_merge_train_not_queen_mean = pd.concat([df_merge_train_not_queen_mean,df_trans2], axis=0, ignore_index=True)
    df_merge_train_not_queen_std = pd.concat([df_merge_train_not_queen_std,df_trans], axis=0, ignore_index=True)
    df_merge_train_not_queen = pd.concat([df_merge_train_not_queen_mean, df_merge_train_not_queen_std], axis=1, ignore_index=True)

df_merge_train_not_queen['Label'] = 0
df_merge_train_not_queen
# Out:
#               0          1          2          3          4          5  \
# 0    -29.076647 -32.123753 -34.923782 -34.891449 -34.630932 -34.650116
# 1    -26.923449 -30.776611 -38.417366 -38.102150 -37.997032 -38.139507
# 2    -51.745136 -52.858482 -56.860138 -56.595230 -56.555725 -56.705753
# 3    -56.109879 -55.585403 -55.299694 -55.452793 -55.259018 -55.279869
# 4    -58.778244 -56.567020 -56.042282 -56.083340 -56.974464 -57.312286
# ...         ...        ...        ...        ...        ...        ...
# 6995 -54.692429 -56.737270 -58.110104 -58.246052 -57.732281 -58.015709
# 6996 -50.883919 -53.445347 -57.537262 -58.117241 -57.791428 -57.780537
# 6997 -57.853447 -57.987541 -57.857147 -57.699448 -58.195427 -57.994305
# 6998 -56.586182 -57.355518 -58.031826 -58.265579 -58.358166 -58.216480
# 6999 -59.770332 -59.531128 -58.503742 -58.645206 -59.735424 -58.826988
#
#               6          7          8          9  ...        165        166  \
# 0    -34.939629 -35.036278 -35.038963 -34.926094  ...  16.504263  16.433264
# 1    -38.090885 -38.372189 -38.414051 -38.446564  ...  19.236444  18.995413
# 2    -56.711472 -57.259277 -57.214027 -57.064018  ...  18.073664  17.999290
# 3    -54.987820 -54.969090 -54.742119 -54.701195  ...  16.739342  16.831470
# 4    -57.558296 -56.608253 -56.128426 -56.416508  ...  17.894051  17.862654
# ...         ...        ...        ...        ...  ...        ...        ...
# 6995 -58.354717 -58.418350 -58.214268 -58.037216  ...  14.531183  14.450150
# 6996 -58.155411 -57.901585 -57.452961 -57.133911  ...  15.146297  14.921658
# 6997 -58.244450 -57.833763 -56.917347 -54.897896  ...  15.638907  15.895249
# 6998 -58.637936 -58.981228 -58.345421 -58.361980  ...  15.045593  15.087381
# 6999 -57.656139 -57.864758 -58.601635 -59.169327  ...  15.992996  16.191641
#
#             167        168        169        170        171        172  \
# 0     16.334555  16.149122  16.167686  16.466049  16.347908  13.189130
# 1     19.029593  19.402189  19.558212  19.354189  19.229954  16.160933
# 2     17.905649  17.744038  17.701893  17.869116  17.957708  17.157703
# 3     16.455135  16.506577  16.510788  16.421669  16.081011  16.268597
# 4     17.697226  17.788013  17.663157  17.769894  17.797598  17.589996
# ...         ...        ...        ...        ...        ...        ...
# 6995  14.626769  14.817113  14.745834  14.843948  14.621048  14.582134
# 6996  14.818048  15.421291  15.858134  15.944130  15.521929  15.296474
# 6997  15.841305  15.691288  15.719182  15.845022  16.357193  15.352203
# 6998  15.059677  15.003215  14.911119  14.952401  14.776394  15.315471
# 6999  16.170538  16.137669  16.111366  16.226336  16.284561  15.997307
#
#             173  Label
# 0     10.836870      0
# 1     12.932262      0
# 2     14.378725      0
# 3     15.351879      0
# 4     16.993740      0
# ...         ...    ...
# 6995  13.063349      0
# 6996  13.542556      0
# 6997  12.189669      0
# 6998  14.747086      0
# 6999  14.492587      0
#
# [7000 rows x 175 columns]

# %% [markdown]
# ## Queen Val

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/val/Queen/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_val_queen = pd.DataFrame()
df_merge_val_queen_mean= pd.DataFrame()
df_merge_val_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
# 996  14.017342      1
# 997  12.944223      1
# 998  11.862497      1
# 999  12.881288      1
#
# [1000 rows x 175 columns]

# %% [markdown]
# ##  Not Queen Val

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/val/NonQueen/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_val_not_queen = pd.DataFrame()
df_merge_val_not_queen_mean= pd.DataFrame()
df_merge_val_not_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
    df_trans2 = df2.mean(axis=0).to_frame().T
    
    df_merge_val_not_queen_mean = pd.concat([df_merge_val_not_queen_mean,df_trans2], axis=0, ignore_index=True)
    df_merge_val_not_queen_std = pd.concat([df_merge_val_not_queen_std,df_trans], axis=0, ignore_index=True)
    df_merge_val_not_queen = pd.concat([df_merge_val_not_queen_mean, df_merge_val_not_queen_std], axis=1, ignore_index=True)


df_merge_val_not_queen['Label'] = 0
df_merge_val_not_queen
# Out:
#              0          1          2          3          4          5  \
# 0   -46.398521 -49.417187 -54.088982 -54.085289 -53.802326 -53.100082
# 1   -53.177490 -53.556606 -56.765289 -56.870689 -57.078976 -55.658066
# 2   -54.136402 -55.250610 -56.931767 -55.998566 -54.815350 -54.999302
# 3   -52.363934 -52.241055 -54.019604 -54.814953 -54.721813 -54.449421
# 4   -57.599514 -55.665009 -55.482403 -54.415386 -53.202290 -54.613987
# ..         ...        ...        ...        ...        ...        ...
# 995 -48.895596 -53.044998 -58.046741 -58.186005 -57.714008 -58.119404
# 996 -54.186577 -55.970329 -59.058281 -58.783947 -58.912079 -59.769489
# 997 -58.011505 -58.447086 -59.182743 -58.833900 -58.072433 -57.561104
# 998 -52.557148 -55.252232 -58.307407 -58.311882 -57.947357 -57.799595
# 999 -55.440907 -56.107849 -58.608444 -59.226982 -59.143978 -58.970673
#
#              6          7          8          9  ...        165        166  \
# 0   -52.784843 -52.535580 -53.465328 -53.234928  ...  16.215813  16.252596
# 1   -55.054268 -56.556911 -56.881706 -56.593796  ...  18.769684  18.842159
# 2   -55.660919 -56.266380 -56.438408 -56.598782  ...  16.754414  16.919336
# 3   -54.127483 -53.924915 -53.815861 -53.750687  ...  18.437414  18.538475
# 4   -55.214489 -55.098721 -54.877602 -54.444107  ...  17.789867  18.071241
# ..         ...        ...        ...        ...  ...        ...        ...
# 995 -58.537239 -58.424145 -58.335148 -57.835976  ...  15.062855  15.065894
# 996 -59.596146 -59.426685 -58.719303 -58.377834  ...  16.016071  16.001236
# 997 -57.689880 -58.566174 -59.333767 -59.554710  ...  16.683853  16.957062
# 998 -58.401573 -58.404560 -58.653664 -58.391319  ...  15.141146  15.167609
# 999 -58.974277 -58.797485 -58.851387 -58.842278  ...  16.772911  16.408298
#
#            167        168        169        170        171        172  \
# 0    16.317583  16.312244  16.444696  16.749063  16.566555  16.309938
# 1    18.614779  18.645027  18.602167  19.023018  19.155350  19.028692
# 2    16.916162  16.616182  17.120520  17.531599  18.085436  17.064604
# 3    18.528084  18.590801  18.658424  19.047298  19.609627  19.581688
# 4    17.988163  18.159016  18.302214  18.036299  17.807859  15.687962
# ..         ...        ...        ...        ...        ...        ...
# 995  15.577929  16.403580  16.555368  16.600365  16.147167  15.949107
# 996  16.406889  20.602947  21.483088  18.781881  16.866245  16.447327
# 997  17.415762  16.741989  16.413843  16.470608  16.360989  16.858980
# 998  15.154697  15.184160  15.062476  15.102503  15.041119  13.345857
# 999  16.416616  16.046024  15.949492  16.045975  15.766612  15.935722
#
#            173  Label
# 0    14.374133      0
# 1    15.906685      0
# 2    13.497451      0
# 3    16.345427      0
# 4    12.554022      0
# ..         ...    ...
# 995  15.185928      0
# 996  13.885487      0
# 997  16.217525      0
# 998  11.064672      0
# 999  15.128445      0
#
# [1000 rows x 175 columns]

# %% [markdown]
# ##  Queen Test

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/test/Queen/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_test_queen = pd.DataFrame()
df_merge_test_queen_mean= pd.DataFrame()
df_merge_test_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
    df_trans2 = df2.mean(axis=0).to_frame().T
    
    df_merge_test_queen_mean = pd.concat([df_merge_test_queen_mean,df_trans2], axis=0, ignore_index=True)
    df_merge_test_queen_std = pd.concat([df_merge_test_queen_std,df_trans], axis=0, ignore_index=True)
    df_merge_test_queen = pd.concat([df_merge_test_queen_mean, df_merge_test_queen_std], axis=1, ignore_index=True)


df_merge_test_queen['Label'] = 1
df_merge_test_queen
# Out:
#               0          1          2          3          4          5  \
# 0    -58.749912 -57.087410 -57.566471 -57.258846 -57.424160 -57.442570
# 1    -50.075211 -52.768837 -58.720257 -59.083858 -58.540504 -58.194122
# 2    -51.733395 -52.699974 -55.013458 -55.012486 -55.230556 -55.230824
# 3    -52.841648 -54.173306 -57.727501 -57.654022 -57.035168 -56.878635
# 4    -57.152905 -55.477932 -55.573807 -55.572826 -55.183998 -55.163048
# ...         ...        ...        ...        ...        ...        ...
# 1995 -35.929008 -39.117664 -42.952515 -43.298832 -43.307117 -42.912857
# 1996 -48.177063 -52.496212 -57.977020 -57.879444 -57.897678 -57.941223
# 1997 -32.054577 -36.282398 -41.829113 -42.176823 -41.758041 -41.333393
# 1998 -54.418346 -54.420708 -56.974686 -57.754414 -57.749943 -58.595886
# 1999 -54.264473 -54.988583 -56.859871 -55.709045 -55.754566 -55.848866
#
#               6          7          8          9  ...        165        166  \
# 0    -57.182785 -55.882820 -55.863102 -56.928623  ...  17.642008  17.582714
# 1    -58.408115 -57.639709 -57.612808 -58.124809  ...  18.402309  18.483269
# 2    -55.109409 -55.014706 -54.851997 -54.911633  ...  16.905172  16.717829
# 3    -57.496994 -57.640251 -57.641747 -57.701328  ...  17.819334  17.934624
# 4    -55.374733 -55.668606 -55.812016 -55.970974  ...  15.561178  15.456081
# ...         ...        ...        ...        ...  ...        ...        ...
# 1995 -41.764355 -41.839958 -42.476505 -42.746624  ...  16.096212  16.265932
# 1996 -57.624031 -57.478470 -58.038467 -57.983997  ...  15.615198  15.535372
# 1997 -40.778152 -41.404652 -41.526245 -40.127155  ...  15.871712  15.663201
# 1998 -58.841007 -58.797459 -58.762859 -58.907562  ...  16.154486  15.997967
# 1999 -56.237217 -55.381870 -54.753025 -55.589470  ...  18.019148  17.579128
#
#             167        168        169        170        171        172  \
# 0     17.748972  17.816242  17.777758  17.631071  18.099718  17.097179
# 1     18.352318  18.390446  18.580595  18.466076  18.118269  16.006807
# 2     16.501062  17.041178  17.325335  17.398813  17.208612  16.949661
# 3     17.743921  17.987829  18.034834  17.789606  18.103970  18.273298
# 4     15.415813  15.403692  15.425058  15.371732  15.157728  15.489707
# ...         ...        ...        ...        ...        ...        ...
# 1995  16.199202  16.076801  16.152260  15.987603  15.818739  15.844724
# 1996  15.406412  15.311232  15.112116  15.224825  15.485583  15.203190
# 1997  17.054253  17.852859  17.191727  16.639851  16.131767  16.122307
# 1998  15.758769  16.016438  16.165159  16.070616  16.396849  16.804071
# 1999  17.355734  17.034803  17.343016  17.490307  17.355762  16.908777
#
#             173  Label
# 0     13.691296      1
# 1     12.658667      1
# 2     14.689698      1
# 3     16.496775      1
# 4     14.222398      1
# ...         ...    ...
# 1995  13.637781      1
# 1996  12.491675      1
# 1997  14.895132      1
# 1998  14.604124      1
# 1999  13.875302      1
#
# [2000 rows x 175 columns]

# %% [markdown]
# ## Not Queen Test

# %%
folder_path = 'D:/Hoc Tap/Python/KY4/AIL303m/data/20k_audio_splitted_dataset-20240201T051135Z-001/20k_audio_splitted_dataset/test/NonQueen/'

wav_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

df_merge_test_not_queen = pd.DataFrame()
df_merge_test_not_queen_mean= pd.DataFrame()
df_merge_test_not_queen_std= pd.DataFrame()

for wav_file in wav_files:
    file_path = os.path.join(folder_path, wav_file)
    
    y, sr = librosa.load(file_path)
    stft_result = librosa.stft(y)
    magnitude = np.abs(stft_result)
    magnitude_db = librosa.amplitude_to_db(magnitude)

    df = pd.DataFrame(magnitude_db)
    df2 = pd.DataFrame(magnitude_db)
    df_trans = df.std(axis=0).to_frame().T
    df_trans2 = df2.mean(axis=0).to_frame().T
    
    df_merge_test_not_queen_mean = pd.concat([df_merge_test_not_queen_mean,df_trans2], axis=0, ignore_index=True)
    df_merge_test_not_queen_std = pd.concat([df_merge_test_not_queen_std,df_trans], axis=0, ignore_index=True)
    df_merge_test_not_queen = pd.concat([df_merge_test_not_queen_mean, df_merge_test_not_queen_std], axis=1, ignore_index=True)

train_set = df_training.sample(frac=1, random_state=42).reset_index(drop=True)
train_set
# Out:
#                0          1          2          3          4          5  \
# 0     -56.505417 -57.082603 -58.330807 -58.342640 -57.707283 -57.341270
# 1     -56.520390 -56.491768 -57.825897 -57.989460 -57.711903 -57.653484
# 2     -31.871143 -36.409519 -42.555763 -42.951214 -42.929817 -42.980019
# 3     -46.683414 -50.069191 -54.475502 -54.666088 -54.684261 -55.105701
# 4     -38.013680 -41.614632 -45.881783 -47.042046 -45.291576 -44.271523
# ...          ...        ...        ...        ...        ...        ...
# 15995 -39.531975 -37.562389 -37.255489 -37.136417 -37.508266 -37.541325
# 15996 -56.935436 -55.022217 -54.580227 -54.783215 -54.951839 -54.798203
# 15997 -46.950039 -50.616520 -52.204514 -52.642696 -52.616966 -52.333607
# 15998 -35.934311 -39.204468 -43.439617 -43.527542 -43.464420 -43.237755
# 15999 -46.999107 -48.099350 -49.516975 -49.876221 -50.806313 -51.736736
#
#                6          7          8          9  ...        165        166  \
# 0     -57.492329 -58.056091 -58.516571 -58.139553  ...  18.502878  18.634920
# 1     -58.423119 -58.195427 -57.724922 -57.216927  ...  18.427074  18.995241
# 2     -42.618187 -42.758636 -43.053364 -43.095913  ...  16.253418  16.477942
# 3     -55.169418 -54.873817 -55.080666 -54.345043  ...  16.190954  16.327129
# 4     -46.023903 -47.546497 -48.756039 -48.906601  ...  15.255904  16.028667
# ...          ...        ...        ...        ...  ...        ...        ...
# 15995 -37.431717 -36.843918 -36.780506 -37.292408  ...  19.125328  19.399071
# 15996 -54.200256 -53.964127 -54.593857 -54.682991  ...  17.243904  17.222795
# 15997 -52.079491 -52.134029 -52.261669 -52.319427  ...  11.817945  11.849458
# 15998 -43.237408 -43.349689 -43.358528 -43.329727  ...  15.873609  15.841694
# 15999 -52.351067 -52.894718 -53.222942 -53.544827  ...  15.135100  17.052479
#
#              167        168        169        170        171        172  \
# 0      18.614521  18.809292  18.667562  18.489502  18.622869  16.594997
# 1      19.373701  19.379606  18.716436  18.668087  18.691431  18.862423
# 2      16.402580  16.360443  16.289650  16.287949  16.354797  15.302044
# 3      16.222219  16.061310  16.410528  16.560448  16.449793  15.984951
# 4      17.038038  16.701490  16.435825  15.593364  15.257956  14.793792
# ...          ...        ...        ...        ...        ...        ...
# 15995  19.219448  19.335188  19.426443  19.212442  19.140902  15.115475
# 15996  17.533155  17.211306  16.965570  16.665766  16.744486  16.774746
# 15997  11.906033  11.618258  11.679255  11.872379  11.696374  11.519532
# 15998  15.806401  15.695400  15.723985  15.715731  15.499297  14.704678
# 15999  16.392334  15.493807  14.343498  14.084717  14.174722  14.102766
#
#              173  Label
# 0      13.128604      0
# 1      18.365414      1
# 2      11.986951      1
# 3      13.144962      1
# 4      12.428308      0
# ...          ...    ...
# 15995  12.052608      0
# 15996  14.821526      1
# 15997  11.506466      1
# 15998  12.035761      1
# 15999  13.270326      0
#
# [16000 rows x 175 columns]

# %%
df_testing = pd.concat([df_merge_test_queen,df_merge_test_not_queen],axis=0, ignore_index=True)
test_set= df_testing.sample(frac=1, random_state=42).reset_index(drop=True)
test_set
# Out:
#               0          1          2          3          4          5  \
# 0    -50.832935 -52.959213 -58.116802 -57.127239 -56.914139 -57.843964
# 1    -51.188568 -53.789341 -56.682381 -57.373627 -58.273525 -57.905937
# 2    -55.415592 -55.712807 -55.469624 -55.308578 -55.506371 -55.700932
# 3    -55.724915 -57.168606 -58.755920 -58.695381 -58.772060 -59.195038
# 4    -48.551609 -51.870167 -57.529968 -57.301998 -57.347569 -57.212925
# ...         ...        ...        ...        ...        ...        ...
# 3995 -55.187649 -55.331242 -55.731945 -55.726196 -55.765881 -55.901844
# 3996 -48.142826 -49.927219 -54.198349 -54.545059 -54.274002 -53.876694
# 3997 -52.910892 -54.180477 -57.566456 -57.802799 -57.539536 -57.294609
# 3998 -39.282539 -37.172073 -37.451721 -37.145260 -36.914619 -36.943985
# 3999 -51.171646 -52.668922 -54.514694 -54.116261 -53.720062 -54.183830
#
#               6          7          8          9  ...        165        166  \
# 0    -57.295254 -57.110851 -57.279556 -56.952232  ...  17.806620  17.866608
# 1    -57.792072 -57.867428 -58.231262 -57.781174  ...  16.017666  15.873588
# 2    -55.198963 -55.124527 -55.548420 -55.142143  ...  16.306417  16.528131
# 3    -59.400269 -59.140141 -58.904411 -58.745724  ...  15.943327  15.923656
# 4    -57.201855 -57.165741 -57.479939 -57.198395  ...  17.731012  18.034086
# ...         ...        ...        ...        ...  ...        ...        ...
# 3995 -55.442387 -55.257874 -55.625820 -56.037796  ...  16.757160  16.422451
# 3996 -53.289524 -53.063904 -53.908432 -54.317883  ...  18.027462  17.625582
# 3997 -57.463802 -57.562584 -57.537117 -57.774986  ...  17.477333  17.952227
# 3998 -37.089725 -37.316750 -37.423195 -37.207531  ...  18.245846  18.192862
# 3999 -54.154507 -54.287224 -54.346020 -54.361153  ...  15.967238  16.455816
#
#             167        168        169        170        171        172  \
# 0     17.762222  18.081104  18.664028  18.778152  18.358458  17.964964
# 1     15.967745  15.711138  15.618593  15.795403  15.988043  15.881493
# 2     16.529879  16.608521  16.211704  16.049870  16.030506  15.744684
# 3     15.751261  16.014271  15.814862  15.695813  15.969248  16.051399
# 4     17.748430  17.904366  18.908449  18.570778  18.167486  16.250751
# ...         ...        ...        ...        ...        ...        ...
# 3995  16.565393  16.636036  16.646559  16.756294  17.013958  15.906150
# 3996  17.818853  17.298119  17.376749  18.391367  18.596090  17.692759
# 3997  18.020781  17.900404  17.933950  17.707752  17.329252  17.518208
# 3998  18.144487  18.247543  18.451239  18.487410  18.179691  18.124140
# 3999  16.690525  15.954542  16.219261  16.090816  16.176571  14.397973
#
#             173  Label
# 0     17.345055      1
# 1     14.976209      0
# 2     15.101121      1
# 3     14.822386      0
# 4     13.123165      0
# ...         ...    ...
# 3995  12.712087      1
# 3996  14.646111      1
# 3997  16.378500      1
# 3998  17.316238      0
# 3999  11.315135      0
#
# [4000 rows x 175 columns]

# %%
y_train = train_set['Label']
X_train = train_set.drop(['Label'], axis=1)
y_test = test_set['Label']
X_test = test_set.drop(['Label'], axis=1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train)
X_test = scaler.fit_transform(X_test)
X_test = pd.DataFrame(X_test)

# %% [markdown]
# ##  Test Grid

# %%
n_estimators = [100,150,200,250,300]
max_features = ['sqrt']
max_depth = [15,20,25,30,35]
min_samples_split = [2]
min_samples_leaf = [1]
bootstrap = [True]

# %%
param_grid = {
    'n_estimators': n_estimators,
    'max_features' : max_features,
    'max_depth' : max_depth,
    'min_samples_split' : min_samples_split,
    'min_samples_leaf' : min_samples_leaf,
    'bootstrap' : bootstrap
}

# %%
RF_model = RandomForestClassifier()

# %%
RF_Grid = GridSearchCV(estimator=RF_model, param_grid=param_grid, cv=3, verbose = 3)
RF_Grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.743 total time=  25.9s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.742 total time=  25.9s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.739 total time=  25.8s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.740 total time=  38.9s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.747 total time=  38.9s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.744 total time=  38.2s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.744 total time=  51.7s
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.744 total time=  51.9s
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.739 total time=  51.7s
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.740 total time= 1.1min
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.746 total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.743 total time= 1.1min
# [CV 1/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.743 total time= 1.3min
# [CV 2/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.750 total time= 1.3min
# [CV 3/3] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.743 total time= 1.3min
# [CV 1/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.749 total time=  29.7s
# [CV 2/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.749 total time=  29.7s
# [CV 3/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.747 total time=  29.4s
# [CV 1/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.743 total time=  44.6s
# [CV 2/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.753 total time=  44.6s
# [CV 3/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.747 total time=  44.4s
# [CV 1/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.749 total time=  59.7s
# [CV 2/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.746 total time=  59.7s
# [CV 3/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.749 total time=  58.9s
# [CV 1/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.748 total time= 1.2min
# [CV 2/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.752 total time= 1.2min
# [CV 3/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.747 total time= 1.2min
# [CV 1/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.751 total time= 1.5min
# [CV 2/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.751 total time= 1.5min
# [CV 3/3] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.747 total time= 1.5min
# [CV 1/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.756 total time=  31.4s
# [CV 2/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.747 total time=  31.5s
# [CV 3/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.749 total time=  31.0s
# [CV 1/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.751 total time=  47.2s
# [CV 2/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.752 total time=  47.3s
# [CV 3/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.753 total time=  46.7s
# [CV 1/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.753 total time= 1.1min
# [CV 2/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.753 total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.751 total time= 1.1min
# [CV 1/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.752 total time= 1.3min
# [CV 2/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.749 total time= 1.3min
# [CV 3/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.749 total time= 1.3min
# [CV 1/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.758 total time= 1.6min
# [CV 2/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.756 total time= 1.6min
# [CV 3/3] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.751 total time= 1.6min
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.753 total time=  32.5s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.749 total time=  32.7s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.744 total time=  31.8s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.756 total time=  48.8s
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.753 total time=  49.2s
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.745 total time=  48.3s
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.756 total time= 1.1min
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.752 total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.752 total time= 1.1min
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.753 total time= 1.4min
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.749 total time= 1.4min
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.752 total time= 1.3min
# [CV 1/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.753 total time= 1.6min
# [CV 2/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.753 total time= 1.6min
# [CV 3/3] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.754 total time= 1.6min
# [CV 1/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.752 total time=  32.6s
# [CV 2/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.747 total time=  32.6s
# [CV 3/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.749 total time=  32.5s
# [CV 1/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.754 total time=  49.2s
# [CV 2/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.749 total time=  49.0s
# [CV 3/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=0.752 total time=  48.5s
# [CV 1/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.753 total time= 1.1min
# [CV 2/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.751 total time= 1.1min
# [CV 3/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.752 total time= 1.1min
# [CV 1/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.755 total time= 1.4min
# [CV 2/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.753 total time= 1.4min
# [CV 3/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.747 total time= 1.3min
# [CV 1/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.757 total time= 1.6min
# [CV 2/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.752 total time= 1.6min
# [CV 3/3] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=0.746 total time= 1.6min
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'max_depth': [15, 20, 25, 30, 35],
#                          'max_features': ['sqrt'], 'min_samples_leaf': [1],
#                          'min_samples_split': [2],
#                          'n_estimators': [100, 150, 200, 250, 300]},
#              verbose=3)

# %%
RF_Grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 25,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
print(f'Train Accuracy: {RF_Grid.score(X_train, y_train)}')
print(f'Test Accuracy: {RF_Grid.score(X_test, y_test)}')
# Out:
# Train Accuracy: 0.997125
# Test Accuracy: 0.765

# %% [markdown]
# ## Testing Invidual

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 30,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 300)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 1.0
# 0.77175

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 20,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 300)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.9755
# 0.7675

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 15,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 300)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.923625
# 0.75125

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 20,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 250)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.97575
# 0.7585

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 20,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 500)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.9751875
# 0.7595

# %%
RF_model = RandomForestClassifier(bootstrap= True,
 max_depth= 15,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 500)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.9231875
# 0.75075
