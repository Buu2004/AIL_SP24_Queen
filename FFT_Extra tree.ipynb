# %%
import os
import librosa
import numpy as np
import pandas as pd

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# **Extract features FFT**

# %%
def _extract_features(file_path, n_fft=2048, hop_length=512):
    y, sr = librosa.load(file_path)
    fft_result = np.abs(np.fft.fft(y))
    magnitude_db = librosa.amplitude_to_db(fft_result)

    df = pd.DataFrame(magnitude_db)
    df_mean = df.mean(axis=0).to_frame()
    df_std = df.std(axis=0).to_frame()
    df_all = pd.concat([df_mean,df_std]).T
    
    return df_all

# %%
def _read_wav(path):
    df_merge = pd.DataFrame()
    for filename in os.listdir(path):
        if filename.endswith(".wav"):
            file_path = os.path.join(path, filename)
            feature = _extract_features(file_path)
            df_merge = pd.concat([df_merge, feature], ignore_index=True)
    return df_merge

# %%
def shuffleArray(array):
    for i in range(len(array) - 1, 0, -1):
        j = np.random.randint(0, i + 1)
        array[i], array[j] = array[j], array[i]

# %%
def train():
    scaler = StandardScaler()

    NoQueen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\train\\NonQueen_train"
    features_NoQueen = _read_wav(NoQueen_path)
    features_NoQueen = scaler.fit_transform(features_NoQueen)

    Queen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\train\\Queen_train"
    features_Queen = _read_wav(Queen_path)
    features_Queen = scaler.fit_transform(features_Queen)

    all_features = np.concatenate((features_NoQueen, features_Queen), axis=0)
    labels_train = np.array([0] * len(features_NoQueen) + [1] * len(features_Queen))

    # Shuffle the data
    all_features = np.column_stack((all_features, labels_train))
    shuffleArray(all_features)

    X_train = all_features[:, :-1]
    y_train = all_features[:, -1]

    return X_train, y_train

# %%
def val():
    scaler = StandardScaler()

    test_NoQueen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\val\\NonQueen"
    features_NoQueen = _read_wav(test_NoQueen_path)
    features_NoQueen = scaler.fit_transform(features_NoQueen)

    Test_Queen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\val\\Queen"
    features_Queen = _read_wav(Test_Queen_path)
    features_Queen = scaler.fit_transform(features_Queen)


    # all_features = features_NoQueen + features_Queen
    all_features = np.concatenate((features_NoQueen, features_Queen), axis=0)
    all_features_array = np.array(all_features)
    
    # Append labels 
    labels_test = np.array([0] * len(features_NoQueen) + [1] * len(features_Queen))

    all_features_array = np.column_stack((all_features_array, labels_test))
    shuffleArray(all_features_array)

    X_val = all_features_array[:, :-1]  
    y_val = all_features_array[:, -1]

    return X_val, y_val

# %%
def test():
    scaler = StandardScaler()

    test_NoQueen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\test\\NonQueen"
    test_NoQueen = _read_wav(test_NoQueen_path)
    test_NoQueen = scaler.fit_transform(test_NoQueen)

    Test_Queen_path = "D:\\1 Ép bê tê\\4 Kỳ 4 DE\\AIL303m\\Data\\Audio\\20k_audio_splitted_dataset\\test\\Queen"
    Test_Queen = _read_wav(Test_Queen_path)
    Test_Queen = scaler.fit_transform(Test_Queen)

    # all_features = test_NoQueen + Test_Queen
    all_features = np.concatenate((test_NoQueen, Test_Queen), axis=0)
    all_features_array = np.array(all_features)
    
    # Append labels 
    labels_test = np.array([0] * len(test_NoQueen) + [1] * len(Test_Queen))

    all_features_array = np.column_stack((all_features_array, labels_test))
    shuffleArray(all_features_array)

    X_test = all_features_array[:, :-1]  
    y_test = all_features_array[:, -1]

    return X_test, y_test

# %%
X_train, labels_train = train()
X_val, labels_val = val()

# %%
X_test, labels_test = test()

# %%
X_train = pd.DataFrame(X_train)
X_train
# Out:
#               0         1
# 0      3.153603 -0.147051
# 1      3.153603 -0.147051
# 2      3.153603 -0.147051
# 3     -0.305795  0.407632
# 4      2.947389  0.301775
# ...         ...       ...
# 13995 -0.213247 -0.608141
# 13996 -0.306249  0.315206
# 13997 -0.724923  0.780730
# 13998  1.754642 -3.493872
# 13999  0.732086 -1.525566
#
# [14000 rows x 2 columns]

# %%
model = ExtraTreesClassifier(bootstrap=True, 
                             criterion='entropy', 
                             max_depth=20, 
                             max_features='sqrt',
                             min_samples_leaf=1,
                             min_samples_split=2, 
                             n_estimators=40, random_state=42)

model.fit(X_train, labels_train)
# Out:
# ExtraTreesClassifier(bootstrap=True, criterion='entropy', max_depth=20,
#                      n_estimators=40, random_state=42)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(labels_test, y_pred)
report = classification_report(labels_test, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.851
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.97      0.92      3433
#          1.0       0.43      0.16      0.23       567
#
#     accuracy                           0.85      4000
#    macro avg       0.65      0.56      0.57      4000
# weighted avg       0.81      0.85      0.82      4000

# %%
n_estimators = [10, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50]
max_features = ['sqrt']
max_depth = [2, 5, 10, 15, 16, 17, 18, 19, 20]
min_samples_split = [2]
min_samples_leaf = [1]
criterion = ['gini', 'entropy']
bootstrap = [True]

param_grid = {
    'criterion' : criterion,
    'n_estimators': n_estimators,
    'max_features' : max_features,
    'max_depth' : max_depth,
    'min_samples_split' : min_samples_split,
    'min_samples_leaf' : min_samples_leaf,
    'bootstrap' : bootstrap
}

ET_model = ExtraTreesClassifier()

ET_Grid = GridSearchCV(estimator=ET_model, param_grid=param_grid, cv=3, verbose = 3)
ET_Grid.fit(X_train, labels_train)
# Out:
# Fitting 3 folds for each of 306 candidates, totalling 918 fits
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.848 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.848 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.848 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.848 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.851 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.850 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.852 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.856 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.853 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.856 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.853 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.858 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.853 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.851 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.855 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.853 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.855 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.852 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.852 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.859 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.851 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.851 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.856 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.852 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.855 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.853 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.852 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.856 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.853 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.857 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.851 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.852 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.852 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.852 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.855 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.851 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.856 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.852 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.859 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.853 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.853 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.856 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.852 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.853 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.856 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.853 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.853 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.862 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.855 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.854 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.862 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.854 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.854 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.861 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.854 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.854 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.861 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.854 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.854 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.862 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.854 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.856 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.862 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.855 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.854 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.862 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.855 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.861 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.855 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.862 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.854 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.855 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.862 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.855 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.862 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.853 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.861 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.855 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.861 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.854 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.862 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.855 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.854 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.861 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.854 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.854 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.861 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.855 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.854 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.861 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.854 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.855 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.866 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.855 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.855 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.865 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.858 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.857 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.866 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.857 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.860 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.865 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.857 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.857 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.865 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.857 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.860 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.866 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.856 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.860 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.867 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.861 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.859 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.866 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.860 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.857 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.866 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.858 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.860 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.866 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.858 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.860 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.866 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.858 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.858 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.865 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.857 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.859 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.865 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.857 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.859 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.864 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.858 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.860 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.865 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.858 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.859 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.866 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.858 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.859 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.865 total time=   0.4s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.858 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.858 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.871 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.861 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.863 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.866 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.860 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.863 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.869 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.859 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.861 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.868 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.860 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.858 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.867 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.859 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.861 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.869 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.862 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.860 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.866 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.859 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.860 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.870 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.862 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.861 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.868 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.860 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.857 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.867 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.861 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.862 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.868 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.859 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.863 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.868 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.860 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.863 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.870 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.861 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.859 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.867 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.858 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.862 total time=   0.5s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.868 total time=   0.4s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.859 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.862 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.868 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.861 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.860 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.867 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.859 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=16, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.860 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.868 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.860 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.856 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.872 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.864 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.859 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.871 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.864 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.865 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.870 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.867 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.860 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.871 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.864 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.863 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.871 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.861 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.866 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.871 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.860 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.860 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.868 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.865 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.861 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.872 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.861 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.863 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.869 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.863 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=gini, max_depth=17, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.865 total time=   0.2s
# ...
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.883 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.871 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.866 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.880 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.871 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.862 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.880 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.871 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.866 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.879 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.874 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.867 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.879 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.874 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.870 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.877 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.872 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.866 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.877 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.871 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.866 total time=   0.3s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.879 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.873 total time=   0.3s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.869 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.878 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.867 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.867 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.880 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.868 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.870 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.881 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.869 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.868 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.877 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.872 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.864 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.877 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.870 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=19, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.864 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.876 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.866 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=0.872 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.879 total time=   0.0s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.873 total time=   0.0s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=20;, score=0.868 total time=   0.0s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.888 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.874 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=22;, score=0.874 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.881 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.874 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=24;, score=0.871 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.883 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.873 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=26;, score=0.868 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.885 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.874 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=28;, score=0.873 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.883 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.873 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=30;, score=0.873 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.885 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.878 total time=   0.1s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=32;, score=0.866 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.882 total time=   0.1s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.874 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=34;, score=0.872 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.889 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.873 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.871 total time=   0.1s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.885 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.874 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=38;, score=0.869 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.883 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.874 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.872 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.885 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.878 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=42;, score=0.870 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.882 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.873 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=44;, score=0.873 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.885 total time=   0.2s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.873 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=46;, score=0.872 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.882 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.868 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=48;, score=0.871 total time=   0.2s
# [CV 1/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.883 total time=   0.3s
# [CV 2/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.873 total time=   0.2s
# [CV 3/3] END bootstrap=True, criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.874 total time=   0.2s
# GridSearchCV(cv=3, estimator=ExtraTreesClassifier(),
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 5, 10, 15, 16, 17, 18, 19, 20],
#                          'max_features': ['sqrt'], 'min_samples_leaf': [1],
#                          'min_samples_split': [2],
#                          'n_estimators': [10, 20, 22, 24, 26, 28, 30, 32, 34,
#                                           36, 38, 40, 42, 44, 46, 48, 50]},
#              verbose=3)

# %%
ET_Grid.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 20}

# %%
print(f'Train Accuracy: {ET_Grid.score(X_train, labels_train)}')
print(f'Test Accuracy: {ET_Grid.score(X_test, labels_test)}')
# Out:
# Train Accuracy: 0.9307142857142857
# Test Accuracy: 0.8505
